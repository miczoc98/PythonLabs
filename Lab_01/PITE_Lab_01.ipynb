# %% [markdown]
# Importing modules and loading data from sklearn dataset.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn as skl

from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression

dataset = load_boston()
df = pd.DataFrame(data = dataset["data"], columns = dataset["feature_names"])
df["MEDV"] = dataset["target"]

print (df.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Creating histograms of average number of room (RM) and property tax (TAX).

# %%
df.hist(column = "RM", bins = range(3, 10))
plt.show()

df.hist(column = "TAX")
plt.show()

# %% [markdown]
# Fitting columns (RM and TAX) against target (MEDV)

# %%
data_types = ["RM", "TAX"]
target = "MEDV"
lr_model = LinearRegression()


for data_type in data_types:
    df.plot(kind = "scatter", x = data_type, y = target)

    data_as_row = np.array(df[data_type]).reshape(-1, 1)
    lr_model.fit(data_as_row, df[target])

    predict = lr_model.predict(data_as_row)
    plt.plot(df[data_type], predict, c = "red")

    score = lr_model.score(data_as_row, df[target])
    
    plt.show()
    print("R-squared value of " + data_type + " fit : " + str(score))
# Out:
# R-squared value of RM fit : 0.4835254559913343
# R-squared value of TAX fit : 0.2195259210442193

# %% [markdown]
# In case of both sets of data we can see correlation between input (RM or TAX) and output. In first case there is strong positive correlation and in the second slightly weaker negative. In both of those linear function is probably best one to describe relation between variables.
